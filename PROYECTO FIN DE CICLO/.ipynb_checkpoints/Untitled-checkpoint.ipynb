# %%
import pandas as pd
import math
from bokeh.plotting import figure, show, output_notebook
from bokeh.io import output_file
from bokeh.palettes import cividis
from bokeh.models import ColumnDataSource
from bokeh.transform import factor_cmap
from bokeh.palettes import plasma
from bokeh.palettes import Spectral6
from bokeh.palettes import magma
from bokeh.palettes import inferno

# %%
cadaveres = pd.read_csv('Documentos/levantamientoCadaveres.csv', encoding = "ISO-8859-1")

# %%
cadaveres
# Out:
#         Zona                       Provincia                        Canton  \
# 0     ZONA 1                      ESMERALDAS                    ESMERALDAS
# 1     ZONA 6                           AZUAY                SEVILLA_DE_ORO
# 2     ZONA 5                        LOS_RIOS                       QUEVEDO
# 3     ZONA 8                          GUAYAS                     GUAYAQUIL
# 4     ZONA 7                            LOJA                     GONZANAMA
# 5     ZONA 5                        LOS_RIOS                        VINCES
# 6     ZONA 3                        COTOPAXI                     LATACUNGA
# 7     ZONA 2                       PICHINCHA                     RUMINAHUI
# 8     ZONA 6                           AZUAY                         GIRON
# 9     ZONA 8                          GUAYAS                     GUAYAQUIL
# 10    ZONA 8                          GUAYAS                     GUAYAQUIL
# 11    ZONA 8                          GUAYAS                     GUAYAQUIL
# 12    ZONA 8                          GUAYAS                     GUAYAQUIL
# 13    ZONA 9                       PICHINCHA                         QUITO
# 14    ZONA 3                      CHIMBORAZO                      RIOBAMBA
# 15    ZONA 8                          GUAYAS                     GUAYAQUIL
# 16    ZONA 5                        LOS_RIOS                       QUEVEDO
# 17    ZONA 5                        LOS_RIOS       SAN_JACINTO_DE_BUENA_FE
# 18    ZONA 5                        LOS_RIOS                       QUEVEDO
# 19    ZONA 2                        ORELLANA  PUERTO_FRANCISCO_DE_ORELLANA
# 20    ZONA 9                       PICHINCHA                         QUITO
# 21    ZONA 9                       PICHINCHA                         QUITO
# 22    ZONA 1                       SUCUMBIOS                   SHUSHUFINDI
# 23    ZONA 8                          GUAYAS                     GUAYAQUIL
# 24    ZONA 9                       PICHINCHA                         QUITO
# 25    ZONA 5                        LOS_RIOS                       QUEVEDO
# 26    ZONA 1                      ESMERALDAS                    ESMERALDAS
# 27    ZONA 8                          GUAYAS                     GUAYAQUIL
# 28    ZONA 8                          GUAYAS                     GUAYAQUIL
# 29    ZONA 6                           AZUAY                        CUENCA
# ...      ...                             ...                           ...
# 1279  ZONA 1                      ESMERALDAS                      QUININDE
# 1280  ZONA 5                          GUAYAS                         BALAO
# 1281  ZONA 7                          EL_ORO                     ARENILLAS
# 1282  ZONA 7                          EL_ORO                     ARENILLAS
# 1283  ZONA 5                        LOS_RIOS                       QUEVEDO
# 1284  ZONA 1                        IMBABURA                        IBARRA
# 1285  ZONA 7                          EL_ORO                    HUAQUILLAS
# 1286  ZONA 7                          EL_ORO                     ARENILLAS
# 1287  ZONA 7                          EL_ORO                     LAS_LAJAS
# 1288  ZONA 4                          MANABI                    PEDERNALES
# 1289  ZONA 4                          MANABI                    PEDERNALES
cadaveres.groupby(['Zona'])['Zona'].count()
# Out:
# Zona
# ZONA 1                209
# ZONA 2                 56
# ZONA 3                 49
# ZONA 4                144
# ZONA 5                276
# ZONA 6                 64
# ZONA 7                 99
# ZONA 8                267
# ZONA 9                144
# ZONA NO DELIMITADA      1
# Name: Zona, dtype: int64

# %%
cadaveres.groupby(['Provincia'])['Zona'].count()
# Out:
# Provincia
# AZUAY                              37
# BOLIVAR                            10
# CANAR                              21
# CARCHI                              9
# CHIMBORAZO                         15
# COTOPAXI                           16
# EL_ORO                             78
# ESMERALDAS                        132
# GUAYAS                            383
# IMBABURA                           23
# LOJA                               17
# LOS_RIOS                          141
# MANABI                             91
# MORONA_SANTIAGO                     7
# NAPO                               10
# ORELLANA                           23
# PASTAZA                             7
# PICHINCHA                         167
# SANTA_ELENA                         9
# SANTO_DOMINGO_DE_LOS_TSACHILAS     53
# SUCUMBIOS                          45
# TUNGURAHUA                         11
# ZAMORA_CHINCHIPE                    4
# Name: Zona, dtype: int64

# %%
cadaveres.groupby(['Sexo'])['Zona'].count()
# Out:
# Sexo
# FEMENINO      186
# MASCULINO    1123
# Name: Zona, dtype: int64

# %%
edadPromedioPorZona = cadaveres.groupby(['Zona'])['Edad'].mean().tolist()

# %%
for l in edadPromedioPorZona:
    print(l)
# Out:
# 35.82914572864322
# 34.945454545454545
# 33.38297872340426
# 35.539568345323744
# 35.75636363636364
# 35.77049180327869
# 35.24742268041237
# 31.074906367041198
# 33.05594405594405
# 52.0

# %%
edadPromedioPorProvincia = cadaveres.groupby(['Provincia'])['Edad'].mean().tolist()

# %%
for l in edadPromedioPorProvincia:
    print(l)
# Out:
# 34.114285714285714
# 38.9
# 40.05
# 41.888888888888886
# 28.642857142857142
# 34.733333333333334
# 33.55263157894737
# 35.774193548387096
# 32.806788511749346
# 34.04545454545455
# 40.76470588235294
# 34.69285714285714
# 36.839080459770116
# 34.142857142857146
# 41.888888888888886
# 33.56521739130435
# 43.857142857142854
# 33.13253012048193
# 35.44444444444444
# 33.36538461538461
# 35.63636363636363
# 30.90909090909091
# 44.0

# %%
edadPromedioPorSexo = cadaveres.groupby(['Sexo'])['Edad'].mean().tolist()

# %%
for l in edadPromedioPorSexo:
    print(l)
# Out:
# 33.26373626373626
# 34.49818511796733

# %%
sexo = ['Masculino', 'Femenino']

# %%
zona = ['ZONA 1', 'ZONA 2', 'ZONA 3', 'ZONA 4', 'ZONA 5', 'ZONA 6', 'ZONA 7','ZONA 8','ZONA 9', 'NO DETERMINADA']

# %%
provincia = ['AZUAY', 'BOLIVAR', 'CANAR', 'CARCHI','CHIMBORAZO', 
             'COTOPAXI', 'EL ORO', 'ESMERALDAS', 'GUAYAS', 
             'IMBABURA', 'LOJA', 'LOS RIOS', 'MANABI', 
             'MORONA SANTIAGO', 'NAPO','ORELLANA', 'PASTAZA', 
             'PICHINCHA', 'SANTA ELENA', 'SANTO DOMINGO DE LOS TSACHILAS',
             'SUCUMBIOS', 'TUNGURAHUA', 'ZAMORA CHINCHIPE']

# %%
color =magma(10)
source = ColumnDataSource(data=dict(zona=zona, edadPromedioPorZona=edadPromedioPorZona, color=color))
output_file("promediosZona.html")
output_notebook()
p = figure(x_range=zona, plot_height=500,plot_width=1000, title="Promedio de Edad de Levantamiento de Cadaveres por Zonas Delimitadas en el mes de Julio de 2014",
           toolbar_location=None, tools="")
p.vbar(x='zona', top='edadPromedioPorZona', width=0.8, color='color', legend = '', source = source)
p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1620">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="875b4522-9f17-4fba-8d61-ee35479d747b" data-root-id="1622"></div>

# %%
color =inferno(23)
source = ColumnDataSource(data=dict(provincia=provincia, edadPromedioPorProvincia=edadPromedioPorProvincia, color=color))
output_file("promediosProvincia.html")
output_notebook()
q = figure(x_range=provincia, plot_height=500,plot_width=1000, title="Promedio de Edad de Levantamiento de Cadaveres por Provincias en el mes de Julio de 2014",
           toolbar_location=None, tools="")
q.vbar(x='provincia', top='edadPromedioPorProvincia', width=0.8, color='color', legend = '', source = source)
q.xgrid.grid_line_color = None
q.xaxis.major_label_orientation = math.pi/2
q.y_range.start = 0

show(q)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1747">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e913420f-3740-4303-a465-2e095a5c6e2e" data-root-id="1749"></div>

# %%
color = Spectral6[4:6]
source = ColumnDataSource(data=dict(sexo=sexo, edadPromedioPorSexo=edadPromedioPorSexo, color=color))
output_file("promediosSexo.html")
output_notebook()
r = figure(x_range=sexo, plot_height=500,plot_width=700, title="Promedio de Edad de Levantamiento de Cadaveres por Sexo en el mes de Julio de 2014",
           toolbar_location=None, tools="")
r.vbar(x='sexo', top='edadPromedioPorSexo', width=0.5, color='color', legend = '', source = source)
r.xgrid.grid_line_color = None
r.y_range.start = 0

show(r)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1895">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d3740498-7494-49eb-ac7f-12524afbe866" data-root-id="1897"></div>

# %%
numeroPorZona = cadaveres.groupby(['Zona'])['Zona'].count().tolist()

# %%
numeroPorProvincia = cadaveres.groupby(['Provincia'])['Zona'].count().tolist()

# %%
numeroPorSexo = cadaveres.groupby(['Sexo'])['Zona'].count().tolist()

# %%
color =plasma(10)
source = ColumnDataSource(data=dict(zona=zona, numeroPorZona=numeroPorZona, color=color))
output_file("numeroZona.html")
output_notebook()
t = figure(x_range=zona, plot_height=500,plot_width=1000, title="Número de Cadaveres Registrados por Zonas Delimitadas en el mes de Julio de 2014",
           toolbar_location=None, tools="")
t.vbar(x='zona', top='numeroPorZona', width=0.8, color='color', legend = '', source = source)
t.xgrid.grid_line_color = None
t.y_range.start = 0

show(t)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2050">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="501e3074-fa1f-413c-a181-3e2e4e432f6b" data-root-id="2052"></div>

# %%
color =cividis(23)
source = ColumnDataSource(data=dict(provincia=provincia, numeroPorProvincia=numeroPorProvincia, color=color))
output_file("numeroProvincia.html")
output_notebook()
s = figure(x_range=provincia, plot_height=500,plot_width=1000, title="Número de Cadaveres Registrados por Provincias en el mes de Julio de 2014",
           toolbar_location=None, tools="")
s.vbar(x='provincia', top='numeroPorProvincia', width=0.8, color='color', legend = '', source = source)
s.xgrid.grid_line_color = None
s.xaxis.major_label_orientation = math.pi/2
s.y_range.start = 0

show(s)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2212">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4a43e3ac-b05f-4c13-9cbd-2ac7f61e7bf2" data-root-id="2214"></div>

# %%
color = Spectral6[:2]
source = ColumnDataSource(data=dict(sexo=sexo, numeroPorSexo=numeroPorSexo, color=color))
output_file("numeroSexo.html")
output_notebook()
u = figure(x_range=sexo, plot_height=500,plot_width=700, title="Número de Cadaveres Registrados por Sexo en el mes de Julio de 2014",
           toolbar_location=None, tools="")
u.vbar(x='sexo', top='numeroPorSexo', width=0.5, color='color', legend = '', source = source)
u.xgrid.grid_line_color = None
u.y_range.start = 0
show(u)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2381">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="211c8094-7af0-45d6-89db-2b872d7bcfa4" data-root-id="2383"></div>

# %%
cadaveres.groupby(['tipo_muert_matriz'])['tipo_muert_matriz'].count()
# Out:
# tipo_muert_matriz
# Asesinatos    840
# Femicidios     32
# Homicidios    407
# Sicariatos     30
# Name: tipo_muert_matriz, dtype: int64

# %%
tipoMuerte = cadaveres.groupby(['tipo_muert_matriz'])['tipo_muert_matriz'].count().tolist()

# %%
for l in tipoMuerte:
    print(l)
# Out:
# 840
# 32
# 407
# 30

# %%
tipo= ['Asesinatos', 'Femicidios', 'Homicidios', 'Sicariatos']

# %%
color = Spectral6[:4]
source = ColumnDataSource(data=dict(tipo=tipo, tipoMuerte=tipoMuerte, color=color))
output_file("tipoMuerte.html")
output_notebook()
w = figure(x_range=tipo, plot_height=500,plot_width=700, title="Número de Cadaveres Registrados por tipo de muerte en el mes de Julio de 2014",
           toolbar_location=None, tools="")
w.vbar(x='tipo', top='tipoMuerte', width=0.5, color='color', legend = '', source = source)
w.xgrid.grid_line_color = None
w.y_range.start = 0
show(w)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2557">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="37dd3d1b-4d7a-434b-994d-974fb637c4c9" data-root-id="2559"></div>

# %%
cadaveres.keys()
# Out:
# Index(['Zona', 'Provincia', 'Canton', 'Distrito', 'Circuito',
#        'Fecha Infracción', 'Hora Infracción', 'tipo_muert_matriz', 'Edad',
#        'Sexo', 'Estado Civil', 'Nacionalidad'],
#       dtype='object')

# %%
tipo = cadaveres.tipo_muert_matriz.unique().tolist()

# %%
tipo
# Out:
# ['Homicidios', 'Femicidios', 'Asesinatos', 'Sicariatos']
